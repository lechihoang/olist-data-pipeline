# %%
# Import PySpark libraries
from pyspark.sql import SparkSession

# Create or get Spark session
spark = SparkSession.builder \
    .appName("Olist Data Analysis") \
    .config("spark.driver.memory", "4g") \
    .getOrCreate()

print("Spark session created successfully!")
print(f"Spark version: {spark.version}")
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/11/09 23:00:12 WARN Utils: Your hostname, Trans-MacBook-Air.local, resolves to a loopback address: 127.0.0.1; using 10.11.6.78 instead (on interface en0)
# 25/11/09 23:00:12 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/11/09 23:00:12 WARN Utils: Your hostname, Trans-MacBook-Air.local, resolves to a loopback address: 127.0.0.1; using 10.11.6.78 instead (on interface en0)
# 25/11/09 23:00:12 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# ...

# %%
# Cell 1: Cấu hình
# ==================================

# 1. Đường dẫn file CSV 
# Update path to match your workspace structure
raw_csv_path = "/Users/tranthihieu/Documents/Brazil Ecommere/data/olist_orders_dataset.csv"

# In ra để kiểm tra
print(f"File CSV nguồn: {raw_csv_path}")
# Out:
# File CSV nguồn: /Users/tranthihieu/Documents/Brazil Ecommere/data/olist_orders_dataset.csv

# %%
# Cell 2: Đọc và Hiển thị (Thử nghiệm)
# ==================================

# Dùng Spark (biến 'spark' đã có sẵn) để đọc file CSV
# - "header=True": Báo cho Spark biết dòng đầu tiên là tên cột
# - "inferSchema=True": Bảo Spark tự động đoán kiểu dữ liệu
df = (spark.read
    .format("csv")
    .option("header", "true")
    .option("inferSchema", "true") 
    .load(raw_csv_path)
)

print("Đọc file thành công! Đang hiển thị dữ liệu...")

# Dùng lệnh 'display' (đã có sẵn) để hiển thị bảng
display(df)
# Out:
# Đọc file thành công! Đang hiển thị dữ liệu...
# DataFrame[order_id: string, customer_id: string, order_status: string, order_purchase_timestamp: timestamp, order_approved_at: timestamp, order_delivered_carrier_date: timestamp, order_delivered_customer_date: timestamp, order_estimated_delivery_date: timestamp]

# %%
df.show(5, truncate=False)
# Out:
# +-------+--------------------+--------------------+------------+
# |summary|            order_id|         customer_id|order_status|
# +-------+--------------------+--------------------+------------+
# |  count|               99441|               99441|       99441|
# |   mean|                NULL|                NULL|        NULL|
# | stddev|                NULL|                NULL|        NULL|
# |    min|00010242fe8c5a6d1...|00012a2ce6f8dcda2...|    approved|
# |    max|fffe41c64501cc87c...|ffffe8b65bbe3087b...| unavailable|
# +-------+--------------------+--------------------+------------+
